# %%
month ="202501"
returnedValue = dbutils.notebook.run(
                                    "/ETL Production/Facts/Process Yelllow Taxi Rides", # Notebook to run 
                                    300, # Timeout in seconds 
                                    {"ProcessMonth":month} # Parameters widgets
)
print(returnedValue)
